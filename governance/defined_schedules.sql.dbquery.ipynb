-- %%
MERGE INTO silver.dims_hvac_schedule AS t
USING (
  SELECT
    v.TenantId,
    v.LocationId,
    v.SublocationId,
    v.DeviceId,
    v.DeviceTyId,
    '06:00' AS StartTimeLocal,
    '01:00' AS EndTimeLocal,
    10 AS GraceStartMin,
    10 AS GraceEndMin,
    true AS IsActive,
    current_timestamp() AS UpdatedAt
  FROM VALUES
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','9322B538-2781-4474-3C83-08DDD9E37FE3','324F3B79-0EEF-45DD-6420-08DDE0FE0D22','09AD0C80-6A1A-4077-B23A-05BA99F8E58C','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','629C200C-0114-41E2-3C84-08DDD9E37FE3','E44E7760-2470-46E8-6425-08DDE0FE0D22','572B8B1C-5C81-45D2-B289-064AAC0DE006','F898B591-C68A-4DCA-50C5-08DDF21B74EE'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','3D88CBEA-06B9-4463-13B3-08DC43934FB8','C7397134-6D3F-4FB3-34A8-08DC43941E6D','8CE6B083-70F6-4C65-7AD7-08DC484D82CA','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','3D88CBEA-06B9-4463-13B3-08DC43934FB8','D7F3A547-2E50-4FF5-34AD-08DC43941E6D','6D978128-9663-4924-7AD8-08DC484D82CA','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('D851AF5F-8956-4548-BFBA-684BD3A6EB5F','82860544-B9C3-403C-A2E8-08DD3FD912C4','EF45ED01-AC81-407F-D9C0-08DD3FEE69C9','1754BCEC-13F0-4DF9-A8B0-2BB1B503631D','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('D851AF5F-8956-4548-BFBA-684BD3A6EB5F','82860544-B9C3-403C-A2E8-08DD3FD912C4','BBA59657-F9DB-4325-D9B7-08DD3FEE69C9','E79787D1-7A8E-4806-AC1B-2EA0BD86A8A1','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('D851AF5F-8956-4548-BFBA-684BD3A6EB5F','7DA4898A-98C2-4E05-A2E9-08DD3FD912C4','E939DCF9-4C1B-4D8E-15D7-08DD4AD02859','65448709-0C2F-4151-9502-30CFE1C6EDBC','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','1A37FA41-9850-4CE5-A2E7-08DD3FD912C4','F44C099A-CE3B-45FB-D9AD-08DD3FEE69C9','DE14B35C-F053-4734-A381-343691B35F01','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','AC3554A0-BA86-4408-94AA-08DD4D13BF4D','D7DAFC7B-B194-4106-7F27-08DD63418751','7433F83E-62EC-47A2-AE5A-451C0F7BECB1','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('D851AF5F-8956-4548-BFBA-684BD3A6EB5F','7DA4898A-98C2-4E05-A2E9-08DD3FD912C4','19F65E5B-D4C1-49B7-D9C1-08DD3FEE69C9','D9F619E6-1F2C-426E-9570-629B43CDA015','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','9322B538-2781-4474-3C83-08DDD9E37FE3','3401C1E0-E149-45C7-6417-08DD0EF0D22','951AB1BF-DDFA-45DF-8B01-64D9166788BE','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','EE27F33C-62E7-4EEA-9A49-08DDD4D13BF4D','5B0B9D74-F840-4126-615D-08DD5B605483','4C2A12D5-72AA-4D7F-90F4-652FCC491513','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','E0AEAB6A-E0C5-4034-3C85-08DDD9E37FE3','905884A8-36F5-4707-6436-08DDE0FE0D22','A724628A-8ABC-4AE2-9ECE-6F0C3DE1C2C8','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','1A37FA41-9850-4CE5-A2E7-08DD3FD912C4','EE9A0AD1-194D-4E62-D9CA-08DD3FEE69C9','3FBEE658-226A-4F04-960E-7E9979C79D12','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','E9CA3CBD-5499-402C-3C86-08DDD9E37FE3','CD470CB0-F7E1-470B-6445-08DDE0FE0D22','8CB4BF92-AEE2-41AC-8E0E-803E12BFDD3E','F898B591-C68A-4DCA-50C5-08DDF21B74EE'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','EE27F33C-62E7-4EEA-9A49-08DDD4D13BF4D','A621B27B-69C8-46B2-615E-08DD5B605483','7EC58114-5C57-4D22-AC0B-8B218889DB09','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','9322B538-2781-4474-3C83-08DDD9E37FE3','3401C1E0-E149-45C7-6417-08DD0EF0D22','2DBE0790-DC58-4A71-A7E4-8E60CE91BDC','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','E9CA3CBD-5499-402C-3C86-08DDD9E37FE3','52E8FF62-E009-4966-644F-08DDE0FE0D22','6A138048-B13F-4317-8506-A028287E8B14','BAFAAC12-ECF2-4DDB-8917-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','AC3554A0-BA86-4408-94AA-08DD4D13BF4D','109E7A76-A306-433B-7F26-08DD63418751','724834F5-B593-4E6C-9C7B-B3E017025318','9EDAA8A7-FCF2-426C-8916-08DC484D6E84'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','E0AEAB6A-E0C5-4034-3C85-08DDD9E37FE3','46AA3786-0591-46E3-6435-08DDE0FE0D22','7E8F020E-AFA7-480E-82F6-BDCECF9099A7','F898B591-C68A-4DCA-50C5-08DDF21B74EE'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','9322B538-2781-4474-3C83-08DDD9E37FE3','3401C1E0-E149-45C7-6417-08DD0EF0D22','CD31BCF0-A7FF-46C6-B417-C555A1B15EAB','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','629C200C-0114-41E2-3C84-08DDD9E37FE3','7FAA0DF0-A577-42C1-6426-08DDE0FE0D22','5479187A-FC83-4A7B-94FA-D1F529844A9B','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('CA99F7DF-F031-444D-A624-68D1F629E5BC','E9CA3CBD-5499-402C-3C86-08DDD9E37FE3','6E12AEC7-FEDD-417B-6446-08DDE0FE0D22','4E39D7F4-CE93-4408-ACAE-F802CFF05793','1AF366EC-24A6-4142-50C4-08DDF21B74EB'),
    ('398B972E-AA03-4D3D-9610-05FD34A2A925','9322B538-2781-4474-3C83-08DDD9E37FE3','412D3CEC-3355-4F76-6416-08DDE0FE0D22','8BE4432E-5A30-40FF-BB1D-FC8DAC35105F','F898B591-C68A-4DCA-50C5-08DDF21B74EE')
  AS v(TenantId, LocationId, SublocationId, DeviceId, DeviceTyId)
) AS s
ON  t.TenantId      = s.TenantId
AND t.DeviceId      = s.DeviceId
AND (t.LocationId   <=> s.LocationId)
AND (t.SublocationId <=> s.SublocationId)
WHEN MATCHED THEN UPDATE SET
  t.DeviceTyId     = s.DeviceTyId,
  t.StartTimeLocal = s.StartTimeLocal,
  t.EndTimeLocal   = s.EndTimeLocal,
  t.GraceStartMin  = s.GraceStartMin,
  t.GraceEndMin    = s.GraceEndMin,
  t.IsActive       = s.IsActive,
  t.UpdatedAt      = s.UpdatedAt
WHEN NOT MATCHED THEN INSERT (
  TenantId, LocationId, SublocationId, DeviceId, DeviceTyId,
  StartTimeLocal, EndTimeLocal, GraceStartMin, GraceEndMin, IsActive, UpdatedAt
) VALUES (
  s.TenantId, s.LocationId, s.SublocationId, s.DeviceId, s.DeviceTyId,
  s.StartTimeLocal, s.EndTimeLocal, s.GraceStartMin, s.GraceEndMin, s.IsActive, s.UpdatedAt
);

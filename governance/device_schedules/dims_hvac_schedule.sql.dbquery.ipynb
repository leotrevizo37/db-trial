-- %%
CREATE TABLE IF NOT EXISTS silver.dims_hvac_schedule (
  TenantId STRING NOT NULL,
  LocationId STRING,
  SublocationId STRING,
  DeviceId STRING,
  DeviceTyId STRING,
  StartTimeLocal STRING NOT NULL,
  EndTimeLocal STRING NOT NULL,
  GraceStartMin INT NOT NULL,
  GraceEndMin INT NOT NULL,
  IsActive BOOLEAN NOT NULL,
  UpdatedAt TIMESTAMP NOT NULL
)
USING DELTA;

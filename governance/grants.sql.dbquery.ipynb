-- %%
REVOKE USE SCHEMA ON SCHEMA trial.bronze FROM `tenant A`;
REVOKE USE SCHEMA ON SCHEMA trial.silver FROM `tenant A`;
REVOKE USE SCHEMA ON SCHEMA trial.gold   FROM `tenant A`;
REVOKE USE SCHEMA ON SCHEMA trial.bronze FROM `tenant B`;
REVOKE USE SCHEMA ON SCHEMA trial.silver FROM `tenant B`;
REVOKE USE SCHEMA ON SCHEMA trial.gold   FROM `tenant B`;
REVOKE USE SCHEMA ON SCHEMA trial.bronze FROM `tenant C`;
REVOKE USE SCHEMA ON SCHEMA trial.silver FROM `tenant C`;
REVOKE USE SCHEMA ON SCHEMA trial.gold   FROM `tenant C`;
REVOKE USE SCHEMA ON SCHEMA trial.bronze FROM `tenant A`;
REVOKE USE SCHEMA ON SCHEMA trial.silver FROM `tenant A`;
REVOKE USE SCHEMA ON SCHEMA trial.gold   FROM `tenant A`;
GRANT USE SCHEMA ON SCHEMA trial.secure TO `tenant A`;
GRANT SELECT ON SCHEMA trial.secure TO `tenant A`;
GRANT SELECT ON SCHEMA trial.bronze TO `tenant A`;
GRANT USE SCHEMA ON SCHEMA trial.secure TO `tenant B`;
GRANT SELECT ON SCHEMA trial.secure TO `tenant B`;
GRANT SELECT ON SCHEMA trial.bronze TO `tenant B`;
GRANT USE SCHEMA ON SCHEMA trial.secure TO `tenant C`;
GRANT SELECT ON SCHEMA trial.secure TO `tenant C`;
GRANT SELECT ON SCHEMA trial.bronze TO `tenant C`;

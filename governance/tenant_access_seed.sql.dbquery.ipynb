-- %%
INSERT INTO security.group_tenant_access VALUES ('tenant A', '398B972E-AA03-4D3D-9610-05FD34A2A925');
INSERT INTO security.group_tenant_access VALUES ('tenant B', 'D851AF5F-8956-4548-BFBA-684BD3A6EB5F');
INSERT INTO security.group_tenant_access VALUES ('tenant C', 'CA99F7DF-F031-444D-A624-68D1F629E5BC');
INSERT INTO security.group_tenant_access VALUES ('ecosat dev', '398B972E-AA03-4D3D-9610-05FD34A2A925');
INSERT INTO security.group_tenant_access VALUES ('ecosat dev', 'D851AF5F-8956-4548-BFBA-684BD3A6EB5F');
INSERT INTO security.group_tenant_access VALUES ('ecosat dev', 'CA99F7DF-F031-444D-A624-68D1F629E5BC');
